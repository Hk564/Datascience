# %% [markdown]
# <a href="https://colab.research.google.com/github/Hk564/Datascience/blob/main/LR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b4f56d32-a419-4c76-851c-4d3edfc0c828" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b4f56d32-a419-4c76-851c-4d3edfc0c828">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
WC =pd.read_csv("wc-at.csv")

# %%
WC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Waist   109 non-null    float64
#  1   AT      109 non-null    float64
# dtypes: float64(2)
# memory usage: 1.8 KB

# %%
WC.corr()
# Out:
#           Waist        AT
# Waist  1.000000  0.818558
# AT     0.818558  1.000000

# %%
import seaborn as sns
sns.displot(WC ['Waist'])

# %%
sns.displot(WC ['AT'])

# %%
import statsmodels.formula.api as smf
model = smf.ols("AT~Waist",data = WC).fit()

# %%
sns.regplot(x="Waist",y="AT",data = WC);

# %%
model.params
# Out:
# Intercept   -215.981488
# Waist          3.458859
# dtype: float64

# %%
(model.rsquared,model.rsquared_adj)
# Out:
# (0.670036893052843, 0.6669531256981966)

# %%
WC
# Out:
#       Waist      AT
# 0     74.75   25.72
# 1     72.60   25.89
# 2     81.80   42.60
# 3     83.95   42.80
# 4     74.65   29.84
# ..      ...     ...
# 104  100.10  124.00
# 105   93.30   62.20
# 106  101.80  133.00
# 107  107.90  208.00
# 108  108.50  208.00
#
# [109 rows x 2 columns]

# %%
newdata = pd.Series([400.6,70.90,25.80,35.70,420])

# %%
df_predict = pd.DataFrame(newdata,columns=['Waist'])

# %%
df_predict
# Out:
#    Waist
# 0  400.6
# 1   70.9
# 2   25.8
# 3   35.7
# 4  420.0

# %%
model.predict(df_predict)
# Out:
# 0    1169.637584
# 1      29.251643
# 2    -126.742916
# 3     -92.500208
# 4    1236.739457
# dtype: float64
